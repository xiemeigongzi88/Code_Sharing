# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
from torch.optim.lr_scheduler import StepLR
#import torch.nn.functional as F

torch.manual_seed(0)
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
batch_size = 64
test_batch_size = 64

# %%
img_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.1307], [0.3081])
])

train_dataset = datasets.MNIST('./data', train=True, download=True, transform=img_transform)
train_dataset, val_dataset = random_split(train_dataset, [50000,10000])
train_loader = DataLoader(train_dataset, batch_size=batch_size,
                          shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=test_batch_size, 
                        shuffle=False)

test_dataset = datasets.MNIST('./data', train=False, download=True, transform=img_transform)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size,
                             shuffle=True, num_workers=2)

# %%
class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28 * 28, 128),
            nn.ReLU(True),
            nn.Linear(128, 64),
            nn.ReLU(True), 
            nn.Linear(64, 32), 
            nn.ReLU(True), 
            nn.Linear(32, 2))
        
        self.decoder = nn.Sequential(
            nn.Linear(2, 32),
            nn.ReLU(True),
            nn.Linear(32, 64),
            nn.ReLU(True),
            nn.Linear(64, 128),
            nn.ReLU(True), 
            nn.Linear(128, 28 * 28), 
            nn.Tanh())

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

ae = autoencoder().to(device)

# %%
ae_criterion = nn.MSELoss()

epochs = 1000
learning_rate = 0.01
#ae_optimizer = torch.optim.Adam(ae.parameters(), lr=0.001, weight_decay=learning_rate)
ae_optimizer = torch.optim.SGD(ae.parameters(), lr=0.5, momentum=0.5)

# %%
train_loss  = []
val_loss = []
for epoch in range(epochs):
    ae.train()
    batch_loss  = []
    for data in train_loader:
        img, _ = data
        img = img.view(img.size(0), -1).to(device)
        output = ae(img)
        
        scheduler = StepLR(ae_optimizer, step_size=50, gamma=0.9)
        loss = ae_criterion(output, img)
        ae_optimizer.zero_grad()
        loss.backward()
        ae_optimizer.step()
        # ===================log========================
        batch_loss.append(loss.item())
    train_loss.append(np.mean(batch_loss))
    
    
    ae.eval()
    batch_loss  = []
    with torch.no_grad():
        for img, y in val_loader:
            img = img.view(img.size(0), -1)
            img, y = img.to(device), y.to(device)
            output = ae(img)
            loss = ae_criterion(output, img)
            batch_loss.append(loss.item())
            val_loss.append(np.mean(batch_loss))
        print(f'Epoch [{epoch + 1}/{epochs}], train loss:{train_loss[-1]:.4f}, val loss:{val_loss[-1]:.4f}')
# Out:
# Epoch [1/1000], train loss:0.6733, val loss:0.6215
# Epoch [2/1000], train loss:0.6103, val loss:0.6074
# Epoch [3/1000], train loss:0.5978, val loss:0.5931
# Epoch [4/1000], train loss:0.5896, val loss:0.5872
# Epoch [5/1000], train loss:0.5827, val loss:0.5808
# Epoch [6/1000], train loss:0.5769, val loss:0.5751
# Epoch [7/1000], train loss:0.5724, val loss:0.5721
# Epoch [8/1000], train loss:0.5682, val loss:0.5670
# Epoch [9/1000], train loss:0.5646, val loss:0.5634
# Epoch [10/1000], train loss:0.5609, val loss:0.5605
# Epoch [11/1000], train loss:0.5590, val loss:0.5586
# Epoch [12/1000], train loss:0.5563, val loss:0.5598
# Epoch [13/1000], train loss:0.5546, val loss:0.5564
# Epoch [14/1000], train loss:0.5530, val loss:0.5543
# Epoch [15/1000], train loss:0.5511, val loss:0.5526
# Epoch [16/1000], train loss:0.5505, val loss:0.5532
# Epoch [17/1000], train loss:0.5488, val loss:0.5495
# Epoch [18/1000], train loss:0.5471, val loss:0.5554
# Epoch [19/1000], train loss:0.5465, val loss:0.5497
# Epoch [20/1000], train loss:0.5441, val loss:0.5475
# Epoch [21/1000], train loss:0.5427, val loss:0.5514
# Epoch [22/1000], train loss:0.5419, val loss:0.5488
# Epoch [23/1000], train loss:0.5406, val loss:0.5429
# Epoch [24/1000], train loss:0.5396, val loss:0.5450
# Epoch [25/1000], train loss:0.5403, val loss:0.5642
# Epoch [26/1000], train loss:0.5385, val loss:0.5429
# Epoch [27/1000], train loss:0.5371, val loss:0.5437
# Epoch [28/1000], train loss:0.5369, val loss:0.5389
# Epoch [29/1000], train loss:0.5370, val loss:0.5484
# Epoch [30/1000], train loss:0.5362, val loss:0.5424
# Epoch [31/1000], train loss:0.5361, val loss:0.5378
# Epoch [32/1000], train loss:0.5351, val loss:0.5530
# Epoch [33/1000], train loss:0.5347, val loss:0.5368
# Epoch [34/1000], train loss:0.5336, val loss:0.5363
# Epoch [35/1000], train loss:0.5330, val loss:0.5345
# Epoch [36/1000], train loss:0.5321, val loss:0.5343
# Epoch [37/1000], train loss:0.5303, val loss:0.5374
# Epoch [38/1000], train loss:0.5315, val loss:0.5326
# Epoch [39/1000], train loss:0.5304, val loss:0.5377
# Epoch [40/1000], train loss:0.5305, val loss:0.5317
# Epoch [41/1000], train loss:0.5298, val loss:0.5334
# Epoch [42/1000], train loss:0.5309, val loss:0.5337
# Epoch [43/1000], train loss:0.5302, val loss:0.5375
# Epoch [44/1000], train loss:0.5297, val loss:0.5360
# Epoch [45/1000], train loss:0.5291, val loss:0.5330
# Epoch [46/1000], train loss:0.5281, val loss:0.5340
# Epoch [47/1000], train loss:0.5273, val loss:0.5302
# Epoch [48/1000], train loss:0.5285, val loss:0.5397
# Epoch [49/1000], train loss:0.5269, val loss:0.5274
# Epoch [50/1000], train loss:0.5266, val loss:0.5271
# Epoch [51/1000], train loss:0.5261, val loss:0.5316
# Epoch [52/1000], train loss:0.5255, val loss:0.5288
# Epoch [53/1000], train loss:0.5256, val loss:0.5309
# Epoch [54/1000], train loss:0.5240, val loss:0.5260
# Epoch [55/1000], train loss:0.5249, val loss:0.5276
# Epoch [56/1000], train loss:0.5247, val loss:0.5263
# Epoch [57/1000], train loss:0.5232, val loss:0.5351
# Epoch [58/1000], train loss:0.5248, val loss:0.5328
# Epoch [59/1000], train loss:0.5248, val loss:0.5263
# Epoch [60/1000], train loss:0.5233, val loss:0.5469
# Epoch [61/1000], train loss:0.5261, val loss:0.5314
# Epoch [62/1000], train loss:0.5256, val loss:0.5292
# Epoch [63/1000], train loss:0.5270, val loss:0.5524
# Epoch [64/1000], train loss:0.5261, val loss:0.5275
# Epoch [65/1000], train loss:0.5246, val loss:0.5268
# Epoch [66/1000], train loss:0.5250, val loss:0.5299
# Epoch [67/1000], train loss:0.5240, val loss:0.5404
# Epoch [68/1000], train loss:0.5249, val loss:0.5257
# Epoch [69/1000], train loss:0.5228, val loss:0.5346
# Epoch [70/1000], train loss:0.5234, val loss:0.5261
# Epoch [71/1000], train loss:0.5230, val loss:0.5269
# Epoch [72/1000], train loss:0.5224, val loss:0.5284
# Epoch [73/1000], train loss:0.5232, val loss:0.5240
# Epoch [74/1000], train loss:0.5230, val loss:0.5257
# Epoch [75/1000], train loss:0.5221, val loss:0.5266
# Epoch [76/1000], train loss:0.5226, val loss:0.5309
# Epoch [77/1000], train loss:0.5224, val loss:0.5227
# Epoch [78/1000], train loss:0.5226, val loss:0.5311
# Epoch [79/1000], train loss:0.5239, val loss:0.5265
# Epoch [80/1000], train loss:0.5215, val loss:0.5233
# Epoch [81/1000], train loss:0.5229, val loss:0.5238
# Epoch [82/1000], train loss:0.5214, val loss:0.5260
# Epoch [83/1000], train loss:0.5200, val loss:0.5234
# Epoch [84/1000], train loss:0.5183, val loss:0.5234
# Epoch [85/1000], train loss:0.5190, val loss:0.5199
# Epoch [86/1000], train loss:0.5207, val loss:0.5224
# Epoch [87/1000], train loss:0.5186, val loss:0.5229
# Epoch [88/1000], train loss:0.5201, val loss:0.5209
# Epoch [89/1000], train loss:0.5188, val loss:0.5212
# Epoch [90/1000], train loss:0.5198, val loss:0.5282
# Epoch [91/1000], train loss:0.5193, val loss:0.5254
# Epoch [92/1000], train loss:0.5196, val loss:0.5202
# Epoch [93/1000], train loss:0.5178, val loss:0.5233
# Epoch [94/1000], train loss:0.5182, val loss:0.5232
# Epoch [95/1000], train loss:0.5176, val loss:0.5214
# Epoch [96/1000], train loss:0.5187, val loss:0.5247
# Epoch [97/1000], train loss:0.5212, val loss:0.5234
# Epoch [98/1000], train loss:0.5202, val loss:0.5219
# Epoch [99/1000], train loss:0.5206, val loss:0.5224
# Epoch [100/1000], train loss:0.5183, val loss:0.5215
# Epoch [101/1000], train loss:0.5183, val loss:0.5190
# Epoch [102/1000], train loss:0.5188, val loss:0.5315
# Epoch [103/1000], train loss:0.5184, val loss:0.5242
# Epoch [104/1000], train loss:0.5176, val loss:0.5194
# Epoch [105/1000], train loss:0.5174, val loss:0.5223
# Epoch [106/1000], train loss:0.5182, val loss:0.5219
# Epoch [107/1000], train loss:0.5168, val loss:0.5193
# Epoch [108/1000], train loss:0.5165, val loss:0.5170
# Epoch [109/1000], train loss:0.5175, val loss:0.5319
# Epoch [110/1000], train loss:0.5195, val loss:0.5197
# Epoch [111/1000], train loss:0.5197, val loss:0.5182
# Epoch [112/1000], train loss:0.5162, val loss:0.5265
# Epoch [113/1000], train loss:0.5195, val loss:0.5292
# Epoch [114/1000], train loss:0.5164, val loss:0.5214
# Epoch [115/1000], train loss:0.5172, val loss:0.5174
# Epoch [116/1000], train loss:0.5156, val loss:0.5177
# Epoch [117/1000], train loss:0.5143, val loss:0.5182
# Epoch [118/1000], train loss:0.5169, val loss:0.5172
# Epoch [119/1000], train loss:0.5169, val loss:0.5203
# Epoch [120/1000], train loss:0.5159, val loss:0.5198
# Epoch [121/1000], train loss:0.5148, val loss:0.5300
# Epoch [122/1000], train loss:0.5136, val loss:0.5178
# Epoch [123/1000], train loss:0.5124, val loss:0.5153
# Epoch [124/1000], train loss:0.5116, val loss:0.5177
# Epoch [125/1000], train loss:0.5124, val loss:0.5155
# Epoch [126/1000], train loss:0.5117, val loss:0.5211
# Epoch [127/1000], train loss:0.5110, val loss:0.5151
# Epoch [128/1000], train loss:0.5116, val loss:0.5149
# Epoch [129/1000], train loss:0.5113, val loss:0.5149
# Epoch [130/1000], train loss:0.5113, val loss:0.5170
# Epoch [131/1000], train loss:0.5109, val loss:0.5151
# Epoch [132/1000], train loss:0.5131, val loss:0.5357
# Epoch [133/1000], train loss:0.5121, val loss:0.5149
# Epoch [134/1000], train loss:0.5112, val loss:0.5227
# Epoch [135/1000], train loss:0.5114, val loss:0.5149
# Epoch [136/1000], train loss:0.5126, val loss:0.5133
# Epoch [137/1000], train loss:0.5124, val loss:0.5134
# Epoch [138/1000], train loss:0.5122, val loss:0.5159
# Epoch [139/1000], train loss:0.5097, val loss:0.5128
# Epoch [140/1000], train loss:0.5105, val loss:0.5173
# Epoch [141/1000], train loss:0.5101, val loss:0.5154
# Epoch [142/1000], train loss:0.5126, val loss:0.5217
# Epoch [143/1000], train loss:0.5130, val loss:0.5267
# Epoch [144/1000], train loss:0.5127, val loss:0.5299
# Epoch [145/1000], train loss:0.5113, val loss:0.5146
# Epoch [146/1000], train loss:0.5102, val loss:0.5179
# Epoch [147/1000], train loss:0.5114, val loss:0.5230
# Epoch [148/1000], train loss:0.5091, val loss:0.5108
# Epoch [149/1000], train loss:0.5084, val loss:0.5161
# Epoch [150/1000], train loss:0.5089, val loss:0.5163
# Epoch [151/1000], train loss:0.5096, val loss:0.5151
# Epoch [152/1000], train loss:0.5091, val loss:0.5120
# Epoch [153/1000], train loss:0.5078, val loss:0.5173
# Epoch [154/1000], train loss:0.5078, val loss:0.5152
# Epoch [155/1000], train loss:0.5082, val loss:0.5140
# Epoch [156/1000], train loss:0.5073, val loss:0.5104
# Epoch [157/1000], train loss:0.5100, val loss:0.5220
# Epoch [158/1000], train loss:0.5119, val loss:0.5275
# Epoch [159/1000], train loss:0.5107, val loss:0.5306
# Epoch [160/1000], train loss:0.5145, val loss:0.5171
# Epoch [161/1000], train loss:0.5120, val loss:0.5189
# Epoch [162/1000], train loss:0.5137, val loss:0.5322
# Epoch [163/1000], train loss:0.5106, val loss:0.5112
# Epoch [164/1000], train loss:0.5089, val loss:0.5188
# Epoch [165/1000], train loss:0.5081, val loss:0.5135
# Epoch [166/1000], train loss:0.5079, val loss:0.5124
# Epoch [167/1000], train loss:0.5082, val loss:0.5192
# Epoch [168/1000], train loss:0.5104, val loss:0.5120
# Epoch [169/1000], train loss:0.5115, val loss:0.5170
# Epoch [170/1000], train loss:0.5099, val loss:0.5121
# Epoch [171/1000], train loss:0.5083, val loss:0.5105
# Epoch [172/1000], train loss:0.5078, val loss:0.5110
# Epoch [173/1000], train loss:0.5084, val loss:0.5301
# Epoch [174/1000], train loss:0.5124, val loss:0.5142
# Epoch [175/1000], train loss:0.5089, val loss:0.5130
# Epoch [176/1000], train loss:0.5094, val loss:0.5132
# Epoch [177/1000], train loss:0.5093, val loss:0.5112
# Epoch [178/1000], train loss:0.5074, val loss:0.5254
# Epoch [179/1000], train loss:0.5068, val loss:0.5118
# Epoch [180/1000], train loss:0.5055, val loss:0.5170
# Epoch [181/1000], train loss:0.5059, val loss:0.5122
# Epoch [182/1000], train loss:0.5062, val loss:0.5114
# Epoch [183/1000], train loss:0.5056, val loss:0.5124
# Epoch [184/1000], train loss:0.5053, val loss:0.5077
# Epoch [185/1000], train loss:0.5073, val loss:0.5149
# Epoch [186/1000], train loss:0.5071, val loss:0.5167
# Epoch [187/1000], train loss:0.5063, val loss:0.5151
# Epoch [188/1000], train loss:0.5066, val loss:0.5150
# Epoch [189/1000], train loss:0.5074, val loss:0.5106
# Epoch [190/1000], train loss:0.5081, val loss:0.5222
# Epoch [191/1000], train loss:0.5070, val loss:0.5096
# Epoch [192/1000], train loss:0.5062, val loss:0.5076
# Epoch [193/1000], train loss:0.5058, val loss:0.5114
# Epoch [194/1000], train loss:0.5068, val loss:0.5235
# Epoch [195/1000], train loss:0.5107, val loss:0.5121
# Epoch [196/1000], train loss:0.5091, val loss:0.5170
# Epoch [197/1000], train loss:0.5077, val loss:0.5130
# Epoch [198/1000], train loss:0.5056, val loss:0.5137
# Epoch [199/1000], train loss:0.5047, val loss:0.5160
# Epoch [200/1000], train loss:0.5048, val loss:0.5114
# Epoch [201/1000], train loss:0.5055, val loss:0.5175
# Epoch [202/1000], train loss:0.5039, val loss:0.5076
# Epoch [203/1000], train loss:0.5057, val loss:0.5074
# Epoch [204/1000], train loss:0.5046, val loss:0.5108
# Epoch [205/1000], train loss:0.5050, val loss:0.5101
# Epoch [206/1000], train loss:0.5035, val loss:0.5075
# Epoch [207/1000], train loss:0.5063, val loss:0.5125
# Epoch [208/1000], train loss:0.5059, val loss:0.5154
# Epoch [209/1000], train loss:0.5049, val loss:0.5057
# Epoch [210/1000], train loss:0.5057, val loss:0.5167
# Epoch [211/1000], train loss:0.5046, val loss:0.5079
# Epoch [212/1000], train loss:0.5038, val loss:0.5083
# Epoch [213/1000], train loss:0.5058, val loss:0.5169
# Epoch [214/1000], train loss:0.5061, val loss:0.5112
# Epoch [215/1000], train loss:0.5055, val loss:0.5094
# Epoch [216/1000], train loss:0.5053, val loss:0.5070
# Epoch [217/1000], train loss:0.5070, val loss:0.5115
# Epoch [218/1000], train loss:0.5037, val loss:0.5108
# Epoch [219/1000], train loss:0.5025, val loss:0.5073
# Epoch [220/1000], train loss:0.5028, val loss:0.5059
# Epoch [221/1000], train loss:0.5022, val loss:0.5092
# Epoch [222/1000], train loss:0.5017, val loss:0.5045
# Epoch [223/1000], train loss:0.5024, val loss:0.5080
# Epoch [224/1000], train loss:0.5030, val loss:0.5078
# Epoch [225/1000], train loss:0.5043, val loss:0.5080
# Epoch [226/1000], train loss:0.5027, val loss:0.5035
# Epoch [227/1000], train loss:0.5030, val loss:0.5199
# Epoch [228/1000], train loss:0.5037, val loss:0.5045
# Epoch [229/1000], train loss:0.5011, val loss:0.5031
# Epoch [230/1000], train loss:0.5016, val loss:0.5035
# Epoch [231/1000], train loss:0.5019, val loss:0.5124
# Epoch [232/1000], train loss:0.5026, val loss:0.5052
# Epoch [233/1000], train loss:0.5043, val loss:0.5065
# Epoch [234/1000], train loss:0.5028, val loss:0.5050
# Epoch [235/1000], train loss:0.5020, val loss:0.5090
# Epoch [236/1000], train loss:0.5024, val loss:0.5089
# Epoch [237/1000], train loss:0.5035, val loss:0.5058
# Epoch [238/1000], train loss:0.5016, val loss:0.5113
# Epoch [239/1000], train loss:0.5025, val loss:0.5086
# Epoch [240/1000], train loss:0.5018, val loss:0.5047
# Epoch [241/1000], train loss:0.5029, val loss:0.5191
# Epoch [242/1000], train loss:0.5030, val loss:0.5132
# Epoch [243/1000], train loss:0.5025, val loss:0.5045
# Epoch [244/1000], train loss:0.5009, val loss:0.5121
# Epoch [245/1000], train loss:0.5019, val loss:0.5073
# Epoch [246/1000], train loss:0.5029, val loss:0.5063
# Epoch [247/1000], train loss:0.5018, val loss:0.5060
# Epoch [248/1000], train loss:0.5044, val loss:0.5071
# Epoch [249/1000], train loss:0.5041, val loss:0.5091
# Epoch [250/1000], train loss:0.5026, val loss:0.5090
# Epoch [251/1000], train loss:0.5057, val loss:0.5151
# Epoch [252/1000], train loss:0.5036, val loss:0.5151
# Epoch [253/1000], train loss:0.5020, val loss:0.5065
# Epoch [254/1000], train loss:0.5028, val loss:0.5152
# Epoch [255/1000], train loss:0.5038, val loss:0.5087
# Epoch [256/1000], train loss:0.5022, val loss:0.5089
# Epoch [257/1000], train loss:0.5016, val loss:0.5252
# Epoch [258/1000], train loss:0.5012, val loss:0.5234
# Epoch [259/1000], train loss:0.5023, val loss:0.5164
# Epoch [260/1000], train loss:0.5021, val loss:0.5058
# Epoch [261/1000], train loss:0.5008, val loss:0.5069
# Epoch [262/1000], train loss:0.5010, val loss:0.5046
# Epoch [263/1000], train loss:0.5010, val loss:0.5085
# Epoch [264/1000], train loss:0.5019, val loss:0.5076
# Epoch [265/1000], train loss:0.5037, val loss:0.5084
# Epoch [266/1000], train loss:0.5019, val loss:0.5020
# Epoch [267/1000], train loss:0.4996, val loss:0.5085
# Epoch [268/1000], train loss:0.5009, val loss:0.5049
# Epoch [269/1000], train loss:0.5009, val loss:0.5045
# Epoch [270/1000], train loss:0.4996, val loss:0.5050
# Epoch [271/1000], train loss:0.5001, val loss:0.5089
# Epoch [272/1000], train loss:0.5024, val loss:0.5203
# Epoch [273/1000], train loss:0.5027, val loss:0.5330
# Epoch [274/1000], train loss:0.5027, val loss:0.5175
# Epoch [275/1000], train loss:0.5015, val loss:0.5213
# Epoch [276/1000], train loss:0.5003, val loss:0.5028
# Epoch [277/1000], train loss:0.5003, val loss:0.5191
# Epoch [278/1000], train loss:0.5006, val loss:0.5023
# Epoch [279/1000], train loss:0.5007, val loss:0.5037
# Epoch [280/1000], train loss:0.5025, val loss:0.5074
# Epoch [281/1000], train loss:0.5019, val loss:0.5082
# Epoch [282/1000], train loss:0.5007, val loss:0.5130
# Epoch [283/1000], train loss:0.4987, val loss:0.5016
# Epoch [284/1000], train loss:0.4997, val loss:0.5160
# Epoch [285/1000], train loss:0.5001, val loss:0.5077
# Epoch [286/1000], train loss:0.5013, val loss:0.5102
# Epoch [287/1000], train loss:0.5015, val loss:0.5039
# Epoch [288/1000], train loss:0.4978, val loss:0.5071
# Epoch [289/1000], train loss:0.4980, val loss:0.5044
# Epoch [290/1000], train loss:0.4981, val loss:0.5048
# Epoch [291/1000], train loss:0.4986, val loss:0.5067
# Epoch [292/1000], train loss:0.5006, val loss:0.5066
# Epoch [293/1000], train loss:0.5002, val loss:0.5113
# Epoch [294/1000], train loss:0.4999, val loss:0.5000
# Epoch [295/1000], train loss:0.5012, val loss:0.5103
# Epoch [296/1000], train loss:0.4998, val loss:0.5084
# Epoch [297/1000], train loss:0.4986, val loss:0.5035
# Epoch [298/1000], train loss:0.5016, val loss:0.5032
# Epoch [299/1000], train loss:0.5010, val loss:0.5050
# Epoch [300/1000], train loss:0.5021, val loss:0.5074
# Epoch [301/1000], train loss:0.4998, val loss:0.5043
# Epoch [302/1000], train loss:0.4999, val loss:0.5137
# Epoch [303/1000], train loss:0.4985, val loss:0.5104
# Epoch [304/1000], train loss:0.4989, val loss:0.5005
# Epoch [305/1000], train loss:0.5002, val loss:0.5131
# Epoch [306/1000], train loss:0.5002, val loss:0.5022
# Epoch [307/1000], train loss:0.4977, val loss:0.5002
# Epoch [308/1000], train loss:0.4974, val loss:0.5021
# Epoch [309/1000], train loss:0.4978, val loss:0.5032
# Epoch [310/1000], train loss:0.4984, val loss:0.5074
# Epoch [311/1000], train loss:0.4982, val loss:0.5013
# Epoch [312/1000], train loss:0.5016, val loss:0.5072
# Epoch [313/1000], train loss:0.5015, val loss:0.5024
# Epoch [314/1000], train loss:0.4986, val loss:0.5121
# Epoch [315/1000], train loss:0.4993, val loss:0.5057
# Epoch [316/1000], train loss:0.4982, val loss:0.5009
# Epoch [317/1000], train loss:0.4983, val loss:0.5171
# Epoch [318/1000], train loss:0.4966, val loss:0.5161
# Epoch [319/1000], train loss:0.4966, val loss:0.5016
# Epoch [320/1000], train loss:0.4979, val loss:0.5007
# Epoch [321/1000], train loss:0.4972, val loss:0.5031
# Epoch [322/1000], train loss:0.4983, val loss:0.5113
# Epoch [323/1000], train loss:0.5019, val loss:0.5166
# Epoch [324/1000], train loss:0.5007, val loss:0.5099
# Epoch [325/1000], train loss:0.5031, val loss:0.5073
# Epoch [326/1000], train loss:0.5006, val loss:0.5081
# Epoch [327/1000], train loss:0.5009, val loss:0.5133
# Epoch [328/1000], train loss:0.5011, val loss:0.5254
# Epoch [329/1000], train loss:0.4992, val loss:0.5042
# Epoch [330/1000], train loss:0.4981, val loss:0.5019
# Epoch [331/1000], train loss:0.4987, val loss:0.5038
# Epoch [332/1000], train loss:0.4982, val loss:0.5053
# Epoch [333/1000], train loss:0.4985, val loss:0.5049
# Epoch [334/1000], train loss:0.4977, val loss:0.5001
# Epoch [335/1000], train loss:0.4970, val loss:0.5089
# Epoch [336/1000], train loss:0.4961, val loss:0.5014
# Epoch [337/1000], train loss:0.4967, val loss:0.5035
# Epoch [338/1000], train loss:0.5008, val loss:0.5012
# Epoch [339/1000], train loss:0.5028, val loss:0.5289
# Epoch [340/1000], train loss:0.5033, val loss:0.5078
# Epoch [341/1000], train loss:0.4993, val loss:0.5009
# Epoch [342/1000], train loss:0.4990, val loss:0.5080
# Epoch [343/1000], train loss:0.4997, val loss:0.5013
# Epoch [344/1000], train loss:0.4981, val loss:0.5032
# Epoch [345/1000], train loss:0.4993, val loss:0.5088
# Epoch [346/1000], train loss:0.4965, val loss:0.5034
# Epoch [347/1000], train loss:0.4967, val loss:0.4995
# Epoch [348/1000], train loss:0.4976, val loss:0.5086
# Epoch [349/1000], train loss:0.4966, val loss:0.5025
# Epoch [350/1000], train loss:0.4958, val loss:0.5060
# Epoch [351/1000], train loss:0.4956, val loss:0.5063
# Epoch [352/1000], train loss:0.4964, val loss:0.5088
# Epoch [353/1000], train loss:0.4963, val loss:0.4987
# Epoch [354/1000], train loss:0.4953, val loss:0.5001
# Epoch [355/1000], train loss:0.4975, val loss:0.5107
# Epoch [356/1000], train loss:0.4969, val loss:0.5216
# Epoch [357/1000], train loss:0.4966, val loss:0.4975
# Epoch [358/1000], train loss:0.4963, val loss:0.5031
# Epoch [359/1000], train loss:0.4953, val loss:0.5010
# Epoch [360/1000], train loss:0.4958, val loss:0.5034
# Epoch [361/1000], train loss:0.4951, val loss:0.4983
# Epoch [362/1000], train loss:0.4966, val loss:0.5274
# Epoch [363/1000], train loss:0.4976, val loss:0.5016
# Epoch [364/1000], train loss:0.4963, val loss:0.5062
# Epoch [365/1000], train loss:0.4972, val loss:0.5040
# Epoch [366/1000], train loss:0.4963, val loss:0.5027
# Epoch [367/1000], train loss:0.4967, val loss:0.5070
# Epoch [368/1000], train loss:0.4950, val loss:0.5078
# Epoch [369/1000], train loss:0.4950, val loss:0.4998
# Epoch [370/1000], train loss:0.4947, val loss:0.4984
# Epoch [371/1000], train loss:0.4949, val loss:0.5096
# Epoch [372/1000], train loss:0.4946, val loss:0.4965
# Epoch [373/1000], train loss:0.4945, val loss:0.5013
# Epoch [374/1000], train loss:0.4941, val loss:0.5034
# Epoch [375/1000], train loss:0.4951, val loss:0.5024
# Epoch [376/1000], train loss:0.4958, val loss:0.5007
# Epoch [377/1000], train loss:0.4965, val loss:0.5047
# Epoch [378/1000], train loss:0.4951, val loss:0.5025
# Epoch [379/1000], train loss:0.4957, val loss:0.5019
# Epoch [380/1000], train loss:0.4964, val loss:0.5022
# Epoch [381/1000], train loss:0.4948, val loss:0.5085
# Epoch [382/1000], train loss:0.4944, val loss:0.4990
# Epoch [383/1000], train loss:0.4938, val loss:0.4990
# Epoch [384/1000], train loss:0.4944, val loss:0.5045
# Epoch [385/1000], train loss:0.4939, val loss:0.4987
# Epoch [386/1000], train loss:0.4954, val loss:0.4999
# Epoch [387/1000], train loss:0.4942, val loss:0.4990
# Epoch [388/1000], train loss:0.4931, val loss:0.5050
# Epoch [389/1000], train loss:0.4945, val loss:0.5014
# Epoch [390/1000], train loss:0.4967, val loss:0.5020
# Epoch [391/1000], train loss:0.4957, val loss:0.5089
# Epoch [392/1000], train loss:0.4956, val loss:0.5000
# Epoch [393/1000], train loss:0.4953, val loss:0.5020
# Epoch [394/1000], train loss:0.4955, val loss:0.5041
# Epoch [395/1000], train loss:0.4983, val loss:0.5062
# Epoch [396/1000], train loss:0.4963, val loss:0.4988
# Epoch [397/1000], train loss:0.4960, val loss:0.5035
# Epoch [398/1000], train loss:0.4980, val loss:0.5210
# Epoch [399/1000], train loss:0.4985, val loss:0.5100
# Epoch [400/1000], train loss:0.4978, val loss:0.5029
# Epoch [401/1000], train loss:0.4979, val loss:0.5009
# Epoch [402/1000], train loss:0.4961, val loss:0.5009
# Epoch [403/1000], train loss:0.4957, val loss:0.5014
# Epoch [404/1000], train loss:0.4946, val loss:0.4989
# Epoch [405/1000], train loss:0.4940, val loss:0.4989
# Epoch [406/1000], train loss:0.4935, val loss:0.5042
# Epoch [407/1000], train loss:0.4944, val loss:0.5028
# Epoch [408/1000], train loss:0.4939, val loss:0.4975
# Epoch [409/1000], train loss:0.4946, val loss:0.5028
# Epoch [410/1000], train loss:0.4934, val loss:0.5043
# Epoch [411/1000], train loss:0.4948, val loss:0.5208
# Epoch [412/1000], train loss:0.4976, val loss:0.5050
# Epoch [413/1000], train loss:0.4952, val loss:0.4977
# Epoch [414/1000], train loss:0.4930, val loss:0.5084
# Epoch [415/1000], train loss:0.4935, val loss:0.5029
# Epoch [416/1000], train loss:0.4927, val loss:0.5059
# Epoch [417/1000], train loss:0.4938, val loss:0.5029
# Epoch [418/1000], train loss:0.4960, val loss:0.5134
# Epoch [419/1000], train loss:0.4944, val loss:0.5072
# Epoch [420/1000], train loss:0.4943, val loss:0.4971
# Epoch [421/1000], train loss:0.4930, val loss:0.5009
# Epoch [422/1000], train loss:0.4934, val loss:0.5030
# Epoch [423/1000], train loss:0.4937, val loss:0.4986
# Epoch [424/1000], train loss:0.4922, val loss:0.5014
# Epoch [425/1000], train loss:0.4926, val loss:0.4988
# Epoch [426/1000], train loss:0.4928, val loss:0.4998
# Epoch [427/1000], train loss:0.4929, val loss:0.4956
# Epoch [428/1000], train loss:0.4923, val loss:0.4999
# Epoch [429/1000], train loss:0.4936, val loss:0.4976
# Epoch [430/1000], train loss:0.4930, val loss:0.4942
# Epoch [431/1000], train loss:0.4921, val loss:0.4974
# Epoch [432/1000], train loss:0.4945, val loss:0.5064
# Epoch [433/1000], train loss:0.4942, val loss:0.4960
# Epoch [434/1000], train loss:0.4937, val loss:0.5058
# Epoch [435/1000], train loss:0.4922, val loss:0.5186
# Epoch [436/1000], train loss:0.4940, val loss:0.4970
# Epoch [437/1000], train loss:0.4925, val loss:0.4975
# Epoch [438/1000], train loss:0.4929, val loss:0.4982
# Epoch [439/1000], train loss:0.4929, val loss:0.5029
# Epoch [440/1000], train loss:0.4927, val loss:0.4997
# Epoch [441/1000], train loss:0.4922, val loss:0.4967
# Epoch [442/1000], train loss:0.4935, val loss:0.5005
# Epoch [443/1000], train loss:0.4937, val loss:0.5124
# Epoch [444/1000], train loss:0.4920, val loss:0.4949
# Epoch [445/1000], train loss:0.4921, val loss:0.4962
# Epoch [446/1000], train loss:0.4916, val loss:0.4963
# Epoch [447/1000], train loss:0.4933, val loss:0.4962
# Epoch [448/1000], train loss:0.4940, val loss:0.5034
# Epoch [449/1000], train loss:0.4958, val loss:0.5023
# Epoch [450/1000], train loss:0.4944, val loss:0.5066
# Epoch [451/1000], train loss:0.4959, val loss:0.4987
# Epoch [452/1000], train loss:0.4954, val loss:0.5047
# Epoch [453/1000], train loss:0.4947, val loss:0.5023
# Epoch [454/1000], train loss:0.4938, val loss:0.4993
# Epoch [455/1000], train loss:0.4943, val loss:0.4960
# Epoch [456/1000], train loss:0.4926, val loss:0.5045
# Epoch [457/1000], train loss:0.4933, val loss:0.4968
# Epoch [458/1000], train loss:0.4942, val loss:0.5045
# Epoch [459/1000], train loss:0.4950, val loss:0.4965
# Epoch [460/1000], train loss:0.4966, val loss:0.5012
# Epoch [461/1000], train loss:0.4956, val loss:0.5057
# Epoch [462/1000], train loss:0.4946, val loss:0.4955
# Epoch [463/1000], train loss:0.4929, val loss:0.4978
# Epoch [464/1000], train loss:0.4926, val loss:0.4973
# Epoch [465/1000], train loss:0.4927, val loss:0.4990
# Epoch [466/1000], train loss:0.4933, val loss:0.5018
# Epoch [467/1000], train loss:0.4916, val loss:0.5029
# Epoch [468/1000], train loss:0.4925, val loss:0.4991
# Epoch [469/1000], train loss:0.4931, val loss:0.4998
# Epoch [470/1000], train loss:0.4956, val loss:0.5077
# Epoch [471/1000], train loss:0.4940, val loss:0.4988
# Epoch [472/1000], train loss:0.4922, val loss:0.4989
# Epoch [473/1000], train loss:0.4923, val loss:0.5254
# Epoch [474/1000], train loss:0.4921, val loss:0.5015
# Epoch [475/1000], train loss:0.4926, val loss:0.5043
# Epoch [476/1000], train loss:0.4948, val loss:0.4983
# Epoch [477/1000], train loss:0.4937, val loss:0.4956
# Epoch [478/1000], train loss:0.4919, val loss:0.5037
# Epoch [479/1000], train loss:0.4936, val loss:0.5079
# Epoch [480/1000], train loss:0.4915, val loss:0.4968
# Epoch [481/1000], train loss:0.4938, val loss:0.4997
# Epoch [482/1000], train loss:0.4943, val loss:0.5024
# Epoch [483/1000], train loss:0.4919, val loss:0.4959
# Epoch [484/1000], train loss:0.4929, val loss:0.5121
# Epoch [485/1000], train loss:0.4947, val loss:0.5004
# Epoch [486/1000], train loss:0.4924, val loss:0.5036
# Epoch [487/1000], train loss:0.4911, val loss:0.4957
# Epoch [488/1000], train loss:0.4908, val loss:0.4973
# Epoch [489/1000], train loss:0.4901, val loss:0.4952
# Epoch [490/1000], train loss:0.4934, val loss:0.4958
# Epoch [491/1000], train loss:0.4931, val loss:0.5009
# Epoch [492/1000], train loss:0.4915, val loss:0.4979
# Epoch [493/1000], train loss:0.4912, val loss:0.4990
# Epoch [494/1000], train loss:0.4912, val loss:0.4969
# Epoch [495/1000], train loss:0.4923, val loss:0.4958
# Epoch [496/1000], train loss:0.4929, val loss:0.4947
# Epoch [497/1000], train loss:0.4910, val loss:0.4993
# Epoch [498/1000], train loss:0.4914, val loss:0.4971
# Epoch [499/1000], train loss:0.4901, val loss:0.4994
# Epoch [500/1000], train loss:0.4905, val loss:0.4963
# Epoch [501/1000], train loss:0.4922, val loss:0.5014
# Epoch [502/1000], train loss:0.4933, val loss:0.5041
# Epoch [503/1000], train loss:0.4946, val loss:0.4999
# Epoch [504/1000], train loss:0.4948, val loss:0.5006
# Epoch [505/1000], train loss:0.4932, val loss:0.4978
# Epoch [506/1000], train loss:0.4931, val loss:0.4974
# Epoch [507/1000], train loss:0.4930, val loss:0.4946
# Epoch [508/1000], train loss:0.4937, val loss:0.4956
# Epoch [509/1000], train loss:0.4933, val loss:0.5086
# Epoch [510/1000], train loss:0.5021, val loss:0.5070
# Epoch [511/1000], train loss:0.5011, val loss:0.5029
# Epoch [512/1000], train loss:0.4966, val loss:0.5101
# Epoch [513/1000], train loss:0.4951, val loss:0.4969
# Epoch [514/1000], train loss:0.4952, val loss:0.4995
# Epoch [515/1000], train loss:0.4981, val loss:0.4947
# Epoch [516/1000], train loss:0.4953, val loss:0.5170
# Epoch [517/1000], train loss:0.4938, val loss:0.4985
# Epoch [518/1000], train loss:0.4933, val loss:0.5041
# Epoch [519/1000], train loss:0.4945, val loss:0.5006
# Epoch [520/1000], train loss:0.4923, val loss:0.4946
# Epoch [521/1000], train loss:0.4913, val loss:0.4948
# Epoch [522/1000], train loss:0.4905, val loss:0.4954
# Epoch [523/1000], train loss:0.4898, val loss:0.4975
# Epoch [524/1000], train loss:0.4913, val loss:0.4956
# Epoch [525/1000], train loss:0.4916, val loss:0.5028
# Epoch [526/1000], train loss:0.4960, val loss:0.4964
# Epoch [527/1000], train loss:0.4969, val loss:0.5024
# Epoch [528/1000], train loss:0.5032, val loss:0.5308
# Epoch [529/1000], train loss:0.4982, val loss:0.5001
# Epoch [530/1000], train loss:0.4963, val loss:0.5040
# Epoch [531/1000], train loss:0.4982, val loss:0.5109
# Epoch [532/1000], train loss:0.4999, val loss:0.5102
# Epoch [533/1000], train loss:0.4973, val loss:0.5001
# Epoch [534/1000], train loss:0.4973, val loss:0.5047
# Epoch [535/1000], train loss:0.4953, val loss:0.4982
# Epoch [536/1000], train loss:0.4960, val loss:0.4990
# Epoch [537/1000], train loss:0.4984, val loss:0.5031
# Epoch [538/1000], train loss:0.5005, val loss:0.4982
# Epoch [539/1000], train loss:0.4972, val loss:0.5122
# Epoch [540/1000], train loss:0.5013, val loss:0.5003
# Epoch [541/1000], train loss:0.4967, val loss:0.5108
# Epoch [542/1000], train loss:0.4962, val loss:0.5075
# Epoch [543/1000], train loss:0.4956, val loss:0.4988
# Epoch [544/1000], train loss:0.4936, val loss:0.5066
# Epoch [545/1000], train loss:0.4958, val loss:0.5000
# Epoch [546/1000], train loss:0.4952, val loss:0.4975
# Epoch [547/1000], train loss:0.5007, val loss:0.5154
# Epoch [548/1000], train loss:0.5007, val loss:0.4987
# Epoch [549/1000], train loss:0.4965, val loss:0.5070
# Epoch [550/1000], train loss:0.4990, val loss:0.4995
# Epoch [551/1000], train loss:0.4970, val loss:0.5055
# Epoch [552/1000], train loss:0.4939, val loss:0.4982
# Epoch [553/1000], train loss:0.4946, val loss:0.4989
# Epoch [554/1000], train loss:0.4957, val loss:0.5076
# Epoch [555/1000], train loss:0.4972, val loss:0.5022
# Epoch [556/1000], train loss:0.4954, val loss:0.4986
# Epoch [557/1000], train loss:0.4938, val loss:0.5063
# Epoch [558/1000], train loss:0.4949, val loss:0.4970
# Epoch [559/1000], train loss:0.4929, val loss:0.4945
# Epoch [560/1000], train loss:0.4927, val loss:0.4973
# Epoch [561/1000], train loss:0.4920, val loss:0.4977
# Epoch [562/1000], train loss:0.4934, val loss:0.4938
# Epoch [563/1000], train loss:0.4943, val loss:0.4985
# Epoch [564/1000], train loss:0.4922, val loss:0.4996
# Epoch [565/1000], train loss:0.4928, val loss:0.5004
# Epoch [566/1000], train loss:0.4908, val loss:0.4935
# Epoch [567/1000], train loss:0.4918, val loss:0.5054
# Epoch [568/1000], train loss:0.4904, val loss:0.4923
# Epoch [569/1000], train loss:0.4904, val loss:0.5033
# Epoch [570/1000], train loss:0.4919, val loss:0.5020
# Epoch [571/1000], train loss:0.4926, val loss:0.4972
# Epoch [572/1000], train loss:0.4920, val loss:0.4956
# Epoch [573/1000], train loss:0.4906, val loss:0.5045
# Epoch [574/1000], train loss:0.4938, val loss:0.5104
# Epoch [575/1000], train loss:0.4946, val loss:0.5050
# Epoch [576/1000], train loss:0.4933, val loss:0.5091
# Epoch [577/1000], train loss:0.4920, val loss:0.4986
# Epoch [578/1000], train loss:0.4913, val loss:0.4953
# Epoch [579/1000], train loss:0.4910, val loss:0.4959
# Epoch [580/1000], train loss:0.4929, val loss:0.4962
# Epoch [581/1000], train loss:0.4933, val loss:0.4986
# Epoch [582/1000], train loss:0.4923, val loss:0.5047
# Epoch [583/1000], train loss:0.4914, val loss:0.5002
# Epoch [584/1000], train loss:0.4926, val loss:0.4989
# Epoch [585/1000], train loss:0.4910, val loss:0.4928
# Epoch [586/1000], train loss:0.4907, val loss:0.4957
# Epoch [587/1000], train loss:0.4905, val loss:0.5006
# Epoch [588/1000], train loss:0.4906, val loss:0.4946
# Epoch [589/1000], train loss:0.4910, val loss:0.4977
# Epoch [590/1000], train loss:0.4918, val loss:0.4940
# Epoch [591/1000], train loss:0.4910, val loss:0.4961
# Epoch [592/1000], train loss:0.4902, val loss:0.4988
# Epoch [593/1000], train loss:0.4912, val loss:0.4965
# Epoch [594/1000], train loss:0.4918, val loss:0.4957
# Epoch [595/1000], train loss:0.4904, val loss:0.4953
# Epoch [596/1000], train loss:0.4924, val loss:0.4986
# Epoch [597/1000], train loss:0.4912, val loss:0.4996
# Epoch [598/1000], train loss:0.4932, val loss:0.4956
# Epoch [599/1000], train loss:0.4902, val loss:0.5056
# Epoch [600/1000], train loss:0.4904, val loss:0.5148
# Epoch [601/1000], train loss:0.4919, val loss:0.4943
# Epoch [602/1000], train loss:0.4932, val loss:0.4977
# Epoch [603/1000], train loss:0.4918, val loss:0.4987
# Epoch [604/1000], train loss:0.4914, val loss:0.4944
# Epoch [605/1000], train loss:0.4900, val loss:0.4936
# Epoch [606/1000], train loss:0.4932, val loss:0.4996
# Epoch [607/1000], train loss:0.4916, val loss:0.4976
# Epoch [608/1000], train loss:0.4917, val loss:0.5101
# Epoch [609/1000], train loss:0.4944, val loss:0.4936
# Epoch [610/1000], train loss:0.4920, val loss:0.4948
# Epoch [611/1000], train loss:0.4912, val loss:0.5017
# Epoch [612/1000], train loss:0.4928, val loss:0.4994
# Epoch [613/1000], train loss:0.4923, val loss:0.4969
# Epoch [614/1000], train loss:0.4937, val loss:0.4959
# Epoch [615/1000], train loss:0.4945, val loss:0.5000
# Epoch [616/1000], train loss:0.4936, val loss:0.5014
# Epoch [617/1000], train loss:0.4922, val loss:0.4970
# Epoch [618/1000], train loss:0.4914, val loss:0.5032
# Epoch [619/1000], train loss:0.4927, val loss:0.5010
# Epoch [620/1000], train loss:0.4923, val loss:0.4933
# Epoch [621/1000], train loss:0.4939, val loss:0.4961
# Epoch [622/1000], train loss:0.4928, val loss:0.5147
# Epoch [623/1000], train loss:0.4917, val loss:0.4923
# Epoch [624/1000], train loss:0.4927, val loss:0.5063
# Epoch [625/1000], train loss:0.4929, val loss:0.4954
# Epoch [626/1000], train loss:0.4913, val loss:0.4990
# Epoch [627/1000], train loss:0.4909, val loss:0.4955
# Epoch [628/1000], train loss:0.4912, val loss:0.5127
# Epoch [629/1000], train loss:0.4900, val loss:0.4930
# Epoch [630/1000], train loss:0.4914, val loss:0.4973
# Epoch [631/1000], train loss:0.4894, val loss:0.4967
# Epoch [632/1000], train loss:0.4895, val loss:0.5048
# Epoch [633/1000], train loss:0.4900, val loss:0.4929
# Epoch [634/1000], train loss:0.4891, val loss:0.4913
# Epoch [635/1000], train loss:0.4944, val loss:0.4960
# Epoch [636/1000], train loss:0.4907, val loss:0.5023
# Epoch [637/1000], train loss:0.4920, val loss:0.4978
# Epoch [638/1000], train loss:0.4924, val loss:0.4970
# Epoch [639/1000], train loss:0.4914, val loss:0.4973
# Epoch [640/1000], train loss:0.4908, val loss:0.4945
# Epoch [641/1000], train loss:0.4913, val loss:0.4963
# Epoch [642/1000], train loss:0.4914, val loss:0.5055
# Epoch [643/1000], train loss:0.4983, val loss:0.5130
# Epoch [644/1000], train loss:0.4926, val loss:0.4942
# Epoch [645/1000], train loss:0.4910, val loss:0.5055
# Epoch [646/1000], train loss:0.4938, val loss:0.5014
# Epoch [647/1000], train loss:0.4928, val loss:0.5065
# Epoch [648/1000], train loss:0.4918, val loss:0.5000
# Epoch [649/1000], train loss:0.4928, val loss:0.5084
# Epoch [650/1000], train loss:0.4939, val loss:0.5046
# Epoch [651/1000], train loss:0.4950, val loss:0.5020
# Epoch [652/1000], train loss:0.4937, val loss:0.4957
# Epoch [653/1000], train loss:0.4928, val loss:0.5028
# Epoch [654/1000], train loss:0.4951, val loss:0.5004
# Epoch [655/1000], train loss:0.4933, val loss:0.4980
# Epoch [656/1000], train loss:0.4916, val loss:0.4970
# Epoch [657/1000], train loss:0.4937, val loss:0.4965
# Epoch [658/1000], train loss:0.4916, val loss:0.4941
# Epoch [659/1000], train loss:0.4912, val loss:0.4984
# Epoch [660/1000], train loss:0.4918, val loss:0.4953
# Epoch [661/1000], train loss:0.4905, val loss:0.4942
# Epoch [662/1000], train loss:0.4932, val loss:0.4962
# Epoch [663/1000], train loss:0.4902, val loss:0.5029
# Epoch [664/1000], train loss:0.4932, val loss:0.5024
# Epoch [665/1000], train loss:0.4911, val loss:0.4986
# Epoch [666/1000], train loss:0.4918, val loss:0.4952
# Epoch [667/1000], train loss:0.4911, val loss:0.4989
# Epoch [668/1000], train loss:0.4904, val loss:0.4924
# Epoch [669/1000], train loss:0.4914, val loss:0.4971
# Epoch [670/1000], train loss:0.4915, val loss:0.4921
# Epoch [671/1000], train loss:0.4909, val loss:0.4952
# Epoch [672/1000], train loss:0.4956, val loss:0.5071
# Epoch [673/1000], train loss:0.4917, val loss:0.4946
# Epoch [674/1000], train loss:0.4916, val loss:0.4975
# Epoch [675/1000], train loss:0.4920, val loss:0.4994
# Epoch [676/1000], train loss:0.4903, val loss:0.4939
# Epoch [677/1000], train loss:0.4900, val loss:0.4917
# Epoch [678/1000], train loss:0.4898, val loss:0.4973
# Epoch [679/1000], train loss:0.4902, val loss:0.4943
# Epoch [680/1000], train loss:0.4914, val loss:0.4930
# Epoch [681/1000], train loss:0.4908, val loss:0.5040
# Epoch [682/1000], train loss:0.4904, val loss:0.4954
# Epoch [683/1000], train loss:0.4913, val loss:0.5047
# Epoch [684/1000], train loss:0.4906, val loss:0.4915
# Epoch [685/1000], train loss:0.4919, val loss:0.4961
# Epoch [686/1000], train loss:0.4919, val loss:0.5260
# Epoch [687/1000], train loss:0.4923, val loss:0.5024
# Epoch [688/1000], train loss:0.4920, val loss:0.4935
# Epoch [689/1000], train loss:0.4940, val loss:0.5027
# Epoch [690/1000], train loss:0.4923, val loss:0.5090
# Epoch [691/1000], train loss:0.4911, val loss:0.5073
# Epoch [692/1000], train loss:0.4926, val loss:0.4965
# Epoch [693/1000], train loss:0.4930, val loss:0.4949
# Epoch [694/1000], train loss:0.4912, val loss:0.5010
# Epoch [695/1000], train loss:0.4917, val loss:0.4935
# Epoch [696/1000], train loss:0.4908, val loss:0.4963
# Epoch [697/1000], train loss:0.4916, val loss:0.5009
# Epoch [698/1000], train loss:0.4922, val loss:0.4979
# Epoch [699/1000], train loss:0.4959, val loss:0.4961
# Epoch [700/1000], train loss:0.4919, val loss:0.5105
# Epoch [701/1000], train loss:0.4931, val loss:0.5027
# Epoch [702/1000], train loss:0.4933, val loss:0.5044
# Epoch [703/1000], train loss:0.4917, val loss:0.4926
# Epoch [704/1000], train loss:0.4942, val loss:0.5233
# Epoch [705/1000], train loss:0.4967, val loss:0.4965
# Epoch [706/1000], train loss:0.4930, val loss:0.5015
# Epoch [707/1000], train loss:0.4946, val loss:0.4958
# Epoch [708/1000], train loss:0.4939, val loss:0.4966
# Epoch [709/1000], train loss:0.4923, val loss:0.4994
# Epoch [710/1000], train loss:0.4917, val loss:0.4931
# Epoch [711/1000], train loss:0.4939, val loss:0.5008
# Epoch [712/1000], train loss:0.4926, val loss:0.4997
# Epoch [713/1000], train loss:0.4929, val loss:0.4974
# Epoch [714/1000], train loss:0.4899, val loss:0.5007
# Epoch [715/1000], train loss:0.4921, val loss:0.4979
# Epoch [716/1000], train loss:0.4899, val loss:0.4997
# Epoch [717/1000], train loss:0.4904, val loss:0.5052
# Epoch [718/1000], train loss:0.4941, val loss:0.4991
# Epoch [719/1000], train loss:0.4922, val loss:0.4958
# Epoch [720/1000], train loss:0.4929, val loss:0.5015
# Epoch [721/1000], train loss:0.5008, val loss:0.5147
# Epoch [722/1000], train loss:0.4954, val loss:0.4994
# Epoch [723/1000], train loss:0.4934, val loss:0.5322
# Epoch [724/1000], train loss:0.4927, val loss:0.5116
# Epoch [725/1000], train loss:0.4919, val loss:0.5040
# Epoch [726/1000], train loss:0.4922, val loss:0.4973
# Epoch [727/1000], train loss:0.4922, val loss:0.4945
# Epoch [728/1000], train loss:0.4911, val loss:0.4946
# Epoch [729/1000], train loss:0.4934, val loss:0.5102
# Epoch [730/1000], train loss:0.4929, val loss:0.5052
# Epoch [731/1000], train loss:0.4898, val loss:0.4930
# Epoch [732/1000], train loss:0.4891, val loss:0.4929
# Epoch [733/1000], train loss:0.4904, val loss:0.4934
# Epoch [734/1000], train loss:0.4902, val loss:0.4974
# Epoch [735/1000], train loss:0.4894, val loss:0.4942
# Epoch [736/1000], train loss:0.4914, val loss:0.4943
# Epoch [737/1000], train loss:0.4916, val loss:0.4945
# Epoch [738/1000], train loss:0.4901, val loss:0.4962
# Epoch [739/1000], train loss:0.4928, val loss:0.5066
# Epoch [740/1000], train loss:0.4899, val loss:0.4928
# Epoch [741/1000], train loss:0.4933, val loss:0.4954
# Epoch [742/1000], train loss:0.4927, val loss:0.4954
# Epoch [743/1000], train loss:0.4938, val loss:0.4931
# Epoch [744/1000], train loss:0.4936, val loss:0.5069
# Epoch [745/1000], train loss:0.5024, val loss:0.4946
# Epoch [746/1000], train loss:0.4913, val loss:0.4938
# Epoch [747/1000], train loss:0.4905, val loss:0.5048
# Epoch [748/1000], train loss:0.4910, val loss:0.4976
# Epoch [749/1000], train loss:0.4918, val loss:0.4956
# Epoch [750/1000], train loss:0.4937, val loss:0.4971
# Epoch [751/1000], train loss:0.4925, val loss:0.4986
# Epoch [752/1000], train loss:0.4944, val loss:0.5082
# Epoch [753/1000], train loss:0.4925, val loss:0.4966
# Epoch [754/1000], train loss:0.4944, val loss:0.5096
# Epoch [755/1000], train loss:0.4939, val loss:0.5013
# Epoch [756/1000], train loss:0.4930, val loss:0.4964
# Epoch [757/1000], train loss:0.4924, val loss:0.5032
# Epoch [758/1000], train loss:0.4925, val loss:0.5025
# Epoch [759/1000], train loss:0.4929, val loss:0.4961
# Epoch [760/1000], train loss:0.4923, val loss:0.5010
# Epoch [761/1000], train loss:0.4923, val loss:0.4955
# Epoch [762/1000], train loss:0.4925, val loss:0.5057
# Epoch [763/1000], train loss:0.4966, val loss:0.4992
# Epoch [764/1000], train loss:0.4936, val loss:0.4975
# Epoch [765/1000], train loss:0.4919, val loss:0.4988
# Epoch [766/1000], train loss:0.4954, val loss:0.5002
# Epoch [767/1000], train loss:0.4946, val loss:0.4999
# Epoch [768/1000], train loss:0.4940, val loss:0.4978
# Epoch [769/1000], train loss:0.4933, val loss:0.5010
# Epoch [770/1000], train loss:0.4924, val loss:0.4992
# Epoch [771/1000], train loss:0.4916, val loss:0.4916
# Epoch [772/1000], train loss:0.4918, val loss:0.5096
# Epoch [773/1000], train loss:0.4926, val loss:0.4974
# Epoch [774/1000], train loss:0.4902, val loss:0.4977
# Epoch [775/1000], train loss:0.4914, val loss:0.5015
# Epoch [776/1000], train loss:0.4903, val loss:0.4985
# Epoch [777/1000], train loss:0.4906, val loss:0.4967
# Epoch [778/1000], train loss:0.4901, val loss:0.5014
# Epoch [779/1000], train loss:0.4902, val loss:0.4997
# Epoch [780/1000], train loss:0.4907, val loss:0.4963
# Epoch [781/1000], train loss:0.4900, val loss:0.5001
# Epoch [782/1000], train loss:0.4910, val loss:0.5002
# Epoch [783/1000], train loss:0.4906, val loss:0.4980
# Epoch [784/1000], train loss:0.4894, val loss:0.4935
# Epoch [785/1000], train loss:0.4902, val loss:0.4992
# Epoch [786/1000], train loss:0.4909, val loss:0.4967
# Epoch [787/1000], train loss:0.4907, val loss:0.4998
# Epoch [788/1000], train loss:0.4927, val loss:0.4944
# Epoch [789/1000], train loss:0.4906, val loss:0.4985
# Epoch [790/1000], train loss:0.4894, val loss:0.4943
# Epoch [791/1000], train loss:0.4898, val loss:0.4949
# Epoch [792/1000], train loss:0.4894, val loss:0.4990
# Epoch [793/1000], train loss:0.4894, val loss:0.4957
# Epoch [794/1000], train loss:0.4922, val loss:0.5130
# Epoch [795/1000], train loss:0.4938, val loss:0.4950
# Epoch [796/1000], train loss:0.4900, val loss:0.4918
# Epoch [797/1000], train loss:0.4899, val loss:0.5032
# Epoch [798/1000], train loss:0.4923, val loss:0.5054
# Epoch [799/1000], train loss:0.4902, val loss:0.4917
# Epoch [800/1000], train loss:0.4894, val loss:0.4957
# Epoch [801/1000], train loss:0.4907, val loss:0.4990
# Epoch [802/1000], train loss:0.4917, val loss:0.4947
# Epoch [803/1000], train loss:0.4914, val loss:0.4958
# Epoch [804/1000], train loss:0.4916, val loss:0.4954
# Epoch [805/1000], train loss:0.4898, val loss:0.4920
# Epoch [806/1000], train loss:0.4893, val loss:0.4952
# Epoch [807/1000], train loss:0.4932, val loss:0.4971
# Epoch [808/1000], train loss:0.4911, val loss:0.5019
# Epoch [809/1000], train loss:0.4936, val loss:0.5007
# Epoch [810/1000], train loss:0.4909, val loss:0.4959
# Epoch [811/1000], train loss:0.4907, val loss:0.5024
# Epoch [812/1000], train loss:0.4912, val loss:0.4949
# Epoch [813/1000], train loss:0.4936, val loss:0.4963
# Epoch [814/1000], train loss:0.4920, val loss:0.5126
# Epoch [815/1000], train loss:0.4926, val loss:0.5006
# Epoch [816/1000], train loss:0.4918, val loss:0.5018
# Epoch [817/1000], train loss:0.4950, val loss:0.5004
# Epoch [818/1000], train loss:0.4963, val loss:0.5059
# Epoch [819/1000], train loss:0.4950, val loss:0.4964
# Epoch [820/1000], train loss:0.4939, val loss:0.5026
# Epoch [821/1000], train loss:0.4980, val loss:0.5040
# Epoch [822/1000], train loss:0.4975, val loss:0.5037
# Epoch [823/1000], train loss:0.4940, val loss:0.4997
# Epoch [824/1000], train loss:0.4921, val loss:0.4977
# Epoch [825/1000], train loss:0.4919, val loss:0.4968
# Epoch [826/1000], train loss:0.4919, val loss:0.4960
# Epoch [827/1000], train loss:0.4914, val loss:0.4999
# Epoch [828/1000], train loss:0.4936, val loss:0.4967
# Epoch [829/1000], train loss:0.4913, val loss:0.5020
# Epoch [830/1000], train loss:0.4909, val loss:0.5035
# Epoch [831/1000], train loss:0.4966, val loss:0.5099
# Epoch [832/1000], train loss:0.4942, val loss:0.5008
# Epoch [833/1000], train loss:0.4924, val loss:0.5116
# Epoch [834/1000], train loss:0.4951, val loss:0.5037
# Epoch [835/1000], train loss:0.4947, val loss:0.4986
# Epoch [836/1000], train loss:0.4945, val loss:0.4985
# Epoch [837/1000], train loss:0.4975, val loss:0.5041
# Epoch [838/1000], train loss:0.4965, val loss:0.5103
# Epoch [839/1000], train loss:0.4963, val loss:0.5036
# Epoch [840/1000], train loss:0.4925, val loss:0.4950
# Epoch [841/1000], train loss:0.4941, val loss:0.4967
# Epoch [842/1000], train loss:0.4938, val loss:0.4977
# Epoch [843/1000], train loss:0.4952, val loss:0.4996
# Epoch [844/1000], train loss:0.4956, val loss:0.5028
# Epoch [845/1000], train loss:0.4936, val loss:0.4941
# Epoch [846/1000], train loss:0.4920, val loss:0.4928
# Epoch [847/1000], train loss:0.4988, val loss:0.5008
# Epoch [848/1000], train loss:0.4959, val loss:0.5373
# Epoch [849/1000], train loss:0.4977, val loss:0.4987
# Epoch [850/1000], train loss:0.4943, val loss:0.4994
# Epoch [851/1000], train loss:0.4945, val loss:0.4945
# Epoch [852/1000], train loss:0.4933, val loss:0.5041
# Epoch [853/1000], train loss:0.4942, val loss:0.4981
# Epoch [854/1000], train loss:0.4980, val loss:0.5074
# Epoch [855/1000], train loss:0.4980, val loss:0.5064
# Epoch [856/1000], train loss:0.4965, val loss:0.4980
# Epoch [857/1000], train loss:0.4928, val loss:0.5025
# Epoch [858/1000], train loss:0.4932, val loss:0.5026
# Epoch [859/1000], train loss:0.4941, val loss:0.4984
# Epoch [860/1000], train loss:0.4927, val loss:0.4919
# Epoch [861/1000], train loss:0.4941, val loss:0.4934
# Epoch [862/1000], train loss:0.4909, val loss:0.4915
# Epoch [863/1000], train loss:0.4904, val loss:0.4977
# Epoch [864/1000], train loss:0.4900, val loss:0.4945
# Epoch [865/1000], train loss:0.4895, val loss:0.4968
# Epoch [866/1000], train loss:0.4941, val loss:0.4955
# Epoch [867/1000], train loss:0.4934, val loss:0.5081
# Epoch [868/1000], train loss:0.4933, val loss:0.5011
# Epoch [869/1000], train loss:0.4914, val loss:0.4953
# Epoch [870/1000], train loss:0.4910, val loss:0.4933
# Epoch [871/1000], train loss:0.4895, val loss:0.5014
# Epoch [872/1000], train loss:0.4919, val loss:0.5136
# Epoch [873/1000], train loss:0.4903, val loss:0.4970
# Epoch [874/1000], train loss:0.4913, val loss:0.4997
# Epoch [875/1000], train loss:0.4910, val loss:0.4946
# Epoch [876/1000], train loss:0.4967, val loss:0.5031
# Epoch [877/1000], train loss:0.4953, val loss:0.4971
# Epoch [878/1000], train loss:0.4925, val loss:0.4998
# Epoch [879/1000], train loss:0.4913, val loss:0.4991
# Epoch [880/1000], train loss:0.4950, val loss:0.4977
# Epoch [881/1000], train loss:0.4926, val loss:0.4951
# Epoch [882/1000], train loss:0.4915, val loss:0.4963
# Epoch [883/1000], train loss:0.4908, val loss:0.5186
# Epoch [884/1000], train loss:0.4905, val loss:0.4971
# Epoch [885/1000], train loss:0.4932, val loss:0.5154
# Epoch [886/1000], train loss:0.4920, val loss:0.5081
# Epoch [887/1000], train loss:0.4915, val loss:0.4909
# Epoch [888/1000], train loss:0.4918, val loss:0.5037
# Epoch [889/1000], train loss:0.5080, val loss:0.5005
# Epoch [890/1000], train loss:0.4952, val loss:0.4987
# Epoch [891/1000], train loss:0.4947, val loss:0.5006
# Epoch [892/1000], train loss:0.4942, val loss:0.5078
# Epoch [893/1000], train loss:0.4906, val loss:0.4964
# Epoch [894/1000], train loss:0.4910, val loss:0.5415
# Epoch [895/1000], train loss:0.4970, val loss:0.5115
# Epoch [896/1000], train loss:0.4941, val loss:0.4957
# Epoch [897/1000], train loss:0.4918, val loss:0.4968
# Epoch [898/1000], train loss:0.4949, val loss:0.5167
# Epoch [899/1000], train loss:0.4949, val loss:0.4966
# Epoch [900/1000], train loss:0.4953, val loss:0.5068
# Epoch [901/1000], train loss:0.4950, val loss:0.5005
# Epoch [902/1000], train loss:0.4969, val loss:0.4980
# Epoch [903/1000], train loss:0.5080, val loss:0.5196
# Epoch [904/1000], train loss:0.5089, val loss:0.5244
# Epoch [905/1000], train loss:0.5077, val loss:0.5078
# Epoch [906/1000], train loss:0.5039, val loss:0.5135
# Epoch [907/1000], train loss:0.5021, val loss:0.5030
# Epoch [908/1000], train loss:0.5006, val loss:0.5019
# Epoch [909/1000], train loss:0.4958, val loss:0.4979
# Epoch [910/1000], train loss:0.4949, val loss:0.5027
# Epoch [911/1000], train loss:0.4950, val loss:0.5020
# Epoch [912/1000], train loss:0.4947, val loss:0.5048
# Epoch [913/1000], train loss:0.4949, val loss:0.4987
# Epoch [914/1000], train loss:0.4963, val loss:0.5010
# Epoch [915/1000], train loss:0.4962, val loss:0.5036
# Epoch [916/1000], train loss:0.4949, val loss:0.4968
# Epoch [917/1000], train loss:0.4950, val loss:0.4992
# Epoch [918/1000], train loss:0.5012, val loss:0.5258
# Epoch [919/1000], train loss:0.4954, val loss:0.4983
# Epoch [920/1000], train loss:0.4949, val loss:0.4971
# Epoch [921/1000], train loss:0.4996, val loss:0.5390
# Epoch [922/1000], train loss:0.5014, val loss:0.5001
# Epoch [923/1000], train loss:0.4958, val loss:0.5022
# Epoch [924/1000], train loss:0.4942, val loss:0.5025
# Epoch [925/1000], train loss:0.4923, val loss:0.5122
# Epoch [926/1000], train loss:0.4936, val loss:0.5015
# Epoch [927/1000], train loss:0.4919, val loss:0.5112
# Epoch [928/1000], train loss:0.4909, val loss:0.5016
# Epoch [929/1000], train loss:0.4935, val loss:0.4959
# Epoch [930/1000], train loss:0.4939, val loss:0.5195
# Epoch [931/1000], train loss:0.4955, val loss:0.4983
# Epoch [932/1000], train loss:0.4924, val loss:0.5573
# Epoch [933/1000], train loss:0.4935, val loss:0.5364
# Epoch [934/1000], train loss:0.4930, val loss:0.4958
# Epoch [935/1000], train loss:0.4929, val loss:0.4990
# Epoch [936/1000], train loss:0.4941, val loss:0.5169
# Epoch [937/1000], train loss:0.4922, val loss:0.5216
# Epoch [938/1000], train loss:0.4930, val loss:0.4987
# Epoch [939/1000], train loss:0.4942, val loss:0.5065
# Epoch [940/1000], train loss:0.4915, val loss:0.4965
# Epoch [941/1000], train loss:0.4923, val loss:0.5035
# Epoch [942/1000], train loss:0.4932, val loss:0.4940
# Epoch [943/1000], train loss:0.4920, val loss:0.4987
# Epoch [944/1000], train loss:0.4927, val loss:0.5010
# Epoch [945/1000], train loss:0.4927, val loss:0.5008
# Epoch [946/1000], train loss:0.4918, val loss:0.5047
# Epoch [947/1000], train loss:0.4917, val loss:0.4962
# Epoch [948/1000], train loss:0.4915, val loss:0.5142
# Epoch [949/1000], train loss:0.4907, val loss:0.4947
# Epoch [950/1000], train loss:0.4933, val loss:0.5091
# Epoch [951/1000], train loss:0.4922, val loss:0.4971
# Epoch [952/1000], train loss:0.4908, val loss:0.4948
# Epoch [953/1000], train loss:0.4909, val loss:0.5027
# Epoch [954/1000], train loss:0.4933, val loss:0.4975
# Epoch [955/1000], train loss:0.4920, val loss:0.4970
# Epoch [956/1000], train loss:0.4926, val loss:0.5118
# Epoch [957/1000], train loss:0.4941, val loss:0.5022
# Epoch [958/1000], train loss:0.4998, val loss:0.5022
# Epoch [959/1000], train loss:0.4968, val loss:0.4972
# Epoch [960/1000], train loss:0.4918, val loss:0.4956
# Epoch [961/1000], train loss:0.4911, val loss:0.4961
# Epoch [962/1000], train loss:0.4917, val loss:0.5165
# Epoch [963/1000], train loss:0.4961, val loss:0.4966
# Epoch [964/1000], train loss:0.4938, val loss:0.4976
# Epoch [965/1000], train loss:0.4926, val loss:0.4967
# Epoch [966/1000], train loss:0.5043, val loss:0.5462
# Epoch [967/1000], train loss:0.5140, val loss:0.5193
# Epoch [968/1000], train loss:0.4997, val loss:0.4996
# Epoch [969/1000], train loss:0.4960, val loss:0.4965
# Epoch [970/1000], train loss:0.4934, val loss:0.4990
# Epoch [971/1000], train loss:0.4923, val loss:0.4944
# Epoch [972/1000], train loss:0.4934, val loss:0.5033
# Epoch [973/1000], train loss:0.4927, val loss:0.5048
# Epoch [974/1000], train loss:0.4940, val loss:0.4977
# Epoch [975/1000], train loss:0.4922, val loss:0.5025
# Epoch [976/1000], train loss:0.4909, val loss:0.5078
# Epoch [977/1000], train loss:0.4917, val loss:0.5022
# Epoch [978/1000], train loss:0.4925, val loss:0.4966
# Epoch [979/1000], train loss:0.4928, val loss:0.4943
# Epoch [980/1000], train loss:0.4937, val loss:0.4984
# Epoch [981/1000], train loss:0.4952, val loss:0.5016
# Epoch [982/1000], train loss:0.5010, val loss:0.4971
# Epoch [983/1000], train loss:0.4949, val loss:0.5025
# Epoch [984/1000], train loss:0.4948, val loss:0.5024
# Epoch [985/1000], train loss:0.4935, val loss:0.4953
# Epoch [986/1000], train loss:0.4936, val loss:0.5045
# Epoch [987/1000], train loss:0.4915, val loss:0.4957
# Epoch [988/1000], train loss:0.4911, val loss:0.5009
# Epoch [989/1000], train loss:0.4921, val loss:0.5125
# Epoch [990/1000], train loss:0.4913, val loss:0.4984
# Epoch [991/1000], train loss:0.4912, val loss:0.4942
# Epoch [992/1000], train loss:0.4903, val loss:0.4943
# Epoch [993/1000], train loss:0.4909, val loss:0.4963
# Epoch [994/1000], train loss:0.4927, val loss:0.4987
# Epoch [995/1000], train loss:0.4912, val loss:0.5184
# Epoch [996/1000], train loss:0.4897, val loss:0.4981
# Epoch [997/1000], train loss:0.4907, val loss:0.4949
# Epoch [998/1000], train loss:0.4916, val loss:0.5090
# Epoch [999/1000], train loss:0.4930, val loss:0.5062
# Epoch [1000/1000], train loss:0.4911, val loss:0.5022

# %%
ae.eval()
batch_loss = []
with torch.no_grad():
    for img, y in test_loader:
        img = img.view(img.size(0), -1)
        img, y = img.cuda(), y.cuda()
        output = ae(img)
        loss = ae_criterion(output, img)
        batch_loss.append(loss.item())
    print(f"Test loss:{np.mean(batch_loss)}")
# Out:
# Test loss:0.5085482958016122

# %%
classifier = nn.Sequential(
                nn.Linear(2, 64),
                nn.ReLU(True),
                nn.Linear(64, 128),
                nn.ReLU(True),
                nn.Linear(128, 10)).to(device)

# %%
classifier_criterion = nn.CrossEntropyLoss()
classifier_optimizer = torch.optim.Adam(classifier.parameters(), lr=learning_rate)

# %%
for epoch in range(epochs):
    classifier.train()
    running_loss = 0.0
    running_acc = 0
    for img, y in train_loader:
        img = img.view(img.size(0), -1)
        img, y = img.to(device), y.to(device)
        # ===================forward=====================
        code_vector = ae.encoder(img)
        y_hat = classifier(code_vector)
        loss = classifier_criterion(y_hat, y)
        # ===================backward====================
        classifier_optimizer.zero_grad()
        loss.backward()
        classifier_optimizer.step()

        # print statistics
        running_loss += loss.item() * img.size(0)
        out = torch.argmax(y_hat.detach(),dim=1)
        assert out.shape==y.shape
        running_acc += (y==out).sum().item()
    print(f"Train Acc:{running_acc*100/len(train_dataset)}%")

    correct = 0
    classifier.eval()
    with torch.no_grad():
        for img, y in val_loader:
            img = img.view(img.size(0), -1)
            img, y = img.cuda(), y.cuda()
            code_vector = ae.encoder(img)
            y_hat = classifier(code_vector)
            y_hat = torch.argmax(y_hat, dim=1)
            acc = (y_hat==y).sum().item()
            correct += acc
    print(f"Val accuracy:{correct*100/len(val_dataset)}%")
# Out:
# Train Acc:77.206%
# Val accuracy:83.34%
# Train Acc:83.182%
# Val accuracy:81.6%
# Train Acc:81.982%
# Val accuracy:83.57%
# Train Acc:82.588%
# Val accuracy:82.95%
# Train Acc:82.994%
# Val accuracy:80.84%
# Train Acc:84.086%
# Val accuracy:82.8%
# Train Acc:83.51%
# Val accuracy:83.81%
# Train Acc:83.728%
# Val accuracy:81.37%
# Train Acc:83.798%
# Val accuracy:83.11%
# Train Acc:84.132%
# Val accuracy:83.48%
# Train Acc:83.448%
# Val accuracy:85.29%
# Train Acc:84.444%
# Val accuracy:84.82%
# Train Acc:84.314%
# Val accuracy:82.7%
# Train Acc:84.43%
# Val accuracy:79.93%
# Train Acc:84.442%
# Val accuracy:84.8%
# Train Acc:84.644%
# Val accuracy:81.72%
# Train Acc:84.188%
# Val accuracy:84.17%
# Train Acc:84.592%
# Val accuracy:84.91%
# Train Acc:84.816%
# Val accuracy:83.78%
# Train Acc:84.65%
# Val accuracy:82.87%
# Train Acc:84.8%
# Val accuracy:84.03%
# Train Acc:84.876%
# Val accuracy:85.41%
# Train Acc:84.478%
# Val accuracy:81.91%
# Train Acc:84.732%
# Val accuracy:84.6%
# Train Acc:84.78%
# Val accuracy:84.53%
# Train Acc:84.856%
# Val accuracy:83.4%
# Train Acc:84.872%
# Val accuracy:85.08%
# Train Acc:84.886%
# Val accuracy:85.48%
# Train Acc:84.824%
# Val accuracy:84.35%
# Train Acc:84.74%
# Val accuracy:84.99%
# Train Acc:83.978%
# Val accuracy:84.94%
# Train Acc:84.646%
# Val accuracy:83.97%
# Train Acc:84.902%
# Val accuracy:84.78%
# Train Acc:84.964%
# Val accuracy:85.01%
# Train Acc:84.972%
# Val accuracy:81.34%
# Train Acc:83.646%
# Val accuracy:85.18%
# Train Acc:84.99%
# Val accuracy:84.67%
# Train Acc:84.97%
# Train Acc:84.956%
# Val accuracy:84.72%
# Train Acc:84.45%
# Val accuracy:84.0%
# Train Acc:84.82%
# Val accuracy:85.0%
# Train Acc:84.542%
# Val accuracy:84.17%
# Train Acc:84.928%
# Val accuracy:84.69%
# Train Acc:84.45%
# Val accuracy:83.83%
# Train Acc:84.882%
# Val accuracy:84.56%
# Train Acc:84.886%
# Val accuracy:84.85%
# Train Acc:84.504%
# Val accuracy:84.23%
# Train Acc:84.882%
# Val accuracy:84.93%
# Train Acc:84.664%
# Val accuracy:84.89%
# Train Acc:84.57%
# Val accuracy:85.24%
# Train Acc:84.89%
# Val accuracy:84.89%
# Train Acc:84.714%
# Val accuracy:84.93%
# Train Acc:84.562%
# Val accuracy:84.72%
# Train Acc:84.84%
# Val accuracy:84.76%
# Train Acc:84.906%
# Val accuracy:85.11%
# Train Acc:84.69%
# Val accuracy:84.66%
# Train Acc:84.796%
# Val accuracy:84.22%
# Train Acc:84.51%
# Val accuracy:83.32%
# Train Acc:84.662%
# Val accuracy:83.79%
# Train Acc:84.584%
# Val accuracy:84.98%
# Train Acc:84.804%
# Val accuracy:83.4%
# Train Acc:84.678%
# Val accuracy:83.94%
# Train Acc:84.528%
# Val accuracy:84.28%
# Train Acc:84.76%
# Val accuracy:85.01%
# Train Acc:84.544%
# Val accuracy:84.26%
# Train Acc:84.618%
# Val accuracy:83.85%
# Train Acc:84.8%
# Val accuracy:84.58%
# Train Acc:84.582%
# Val accuracy:81.17%
# Train Acc:84.784%
# Val accuracy:84.42%
# Train Acc:84.718%
# Val accuracy:84.6%
# Train Acc:84.59%
# Val accuracy:83.72%
# Train Acc:84.772%
# Val accuracy:84.53%
# Train Acc:84.696%
# Val accuracy:84.74%
# Train Acc:84.192%
# Val accuracy:81.96%
# Train Acc:84.114%
# Val accuracy:84.32%
# Train Acc:84.266%
# Val accuracy:85.42%
# Train Acc:84.672%
# Val accuracy:81.31%
# Train Acc:84.87%
# Val accuracy:83.75%
# Train Acc:84.34%
# Val accuracy:84.72%
# Train Acc:84.602%
# Val accuracy:82.63%
# Train Acc:84.606%
# Val accuracy:84.62%
# Train Acc:84.828%
# Val accuracy:82.43%
# Train Acc:84.802%
# Val accuracy:83.54%
# Train Acc:84.474%
# Val accuracy:84.22%
# Train Acc:84.574%
# Val accuracy:84.99%
# Train Acc:84.86%
# Val accuracy:84.56%
# Train Acc:83.782%
# Val accuracy:85.03%
# Train Acc:84.696%
# Val accuracy:83.93%
# Train Acc:84.486%
# Val accuracy:82.95%
# Train Acc:84.148%
# Val accuracy:84.61%

# %%
# evaluate your model on the never-seen-before test data
classifier.eval()
correct = 0
with torch.no_grad():
    for img, y in test_loader:
        img = img.view(img.size(0), -1)
        img, y = img.cuda(), y.cuda()
        code_vector = ae.encoder(img)
        y_hat = classifier(code_vector)
        y_hat = torch.argmax(y_hat, dim=1)
        acc = (y_hat==y).sum().item()
        correct += acc
    print(f"Test accuracy:{correct*100/len(test_dataset)}%")
# Out:
# Test accuracy:84.75%
